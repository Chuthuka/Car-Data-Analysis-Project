# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\NGC\Desktop\Python data analysis projects\Project 5\2. Cars Data.csv")

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %% [markdown]
# **1. ----Data Cleaning----**

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data['Cylinders'].fillna(data['Cylinders'].mean()) #Cylindersc column filled null values with its mean
# Out:
# 0      6.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 427    5.0
# 428    5.0
# 429    6.0
# 430    4.0
# 431    5.0
# Name: Cylinders, Length: 432, dtype: float64

# %%
data['Model'].fillna(data['Model'].mode()[0], inplace=True) #Model column filled null values with its mode(mode() used becoz of string values)

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          0
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data['Make'].fillna(data['Make'].mode()[0], inplace=True) # Make column filled null values with its mode(mode() used becoz of string values)

# %%
data['Type'] = data['Type'].fillna(data['Type'].mode()[0]) # Type column filled null values with its mode(mode() used becoz of string values)

# %%
data['Origin'].fillna(data['Origin'].mode()[0]) # Make column filled null values with its mode(mode() used becoz of string values)
# Out:
# 0        Asia
# 1        Asia
# 2        Asia
# 3        Asia
# 4        Asia
#         ...
# 427    Europe
# 428    Europe
# 429    Europe
# 430    Europe
# 431    Europe
# Name: Origin, Length: 432, dtype: object

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data['DriveTrain'].fillna(data['DriveTrain'].mode()[0]) # DriveTrain column filled null values with its mode(mode() used becoz of string values)
# Out:
# 0        All
# 1      Front
# 2      Front
# 3      Front
# 4      Front
#        ...
# 427    Front
# 428    Front
# 429    Front
# 430    Front
# 431      All
# Name: DriveTrain, Length: 432, dtype: object

# %%
data['MSRP'].fillna(data['MSRP'].mode()[0], inplace=True) #MSRP column filled null values with its mode() becoz its mix of numbers and strings

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data['Invoice'].fillna(data['Invoice'].mode()[0]) #Invoice column filled null values with its mode() becoz its mix of numbers and strings
# Out:
# 0      $33,337
# 1      $21,761
# 2      $24,647
# 3      $30,299
# 4      $39,014
#          ...
# 427    $38,203
# 428    $40,083
# 429    $42,573
# 430    $24,641
# 431    $33,112
# Name: Invoice, Length: 432, dtype: object

# %%
data['EngineSize'].fillna(data['EngineSize'].mean()) #EngineSize column filled null values with its mean
# Out:
# 0      3.5
# 1      2.0
# 2      2.4
# 3      3.2
# 4      3.5
#       ...
# 427    2.4
# 428    2.3
# 429    2.9
# 430    1.9
# 431    2.5
# Name: EngineSize, Length: 432, dtype: float64

# %%
data['Horsepower'].fillna(data['Horsepower'].mean()) #Horsepower column filled null values with its mean
# Out:
# 0      265.0
# 1      200.0
# 2      200.0
# 3      270.0
# 4      225.0
#        ...
# 427    197.0
# 428    242.0
# 429    268.0
# 430    170.0
# 431    208.0
# Name: Horsepower, Length: 432, dtype: float64

# %%
data['MPG_City'].fillna(data['MPG_City'].mean()) #MPG_City column filled null values with its mean
# Out:
# 0      17.0
# 1      24.0
# 2      22.0
# 3      20.0
# 4      18.0
#        ...
# 427    21.0
# 428    20.0
# 429    19.0
# 430    22.0
# 431    20.0
# Name: MPG_City, Length: 432, dtype: float64

# %%
data['MPG_Highway'].fillna(data['MPG_Highway'].mean()) #MPG_Highway column filled null values with its mean
# Out:
# 0      23.0
# 1      31.0
# 2      29.0
# 3      28.0
# 4      24.0
#        ...
# 427    28.0
# 428    26.0
# 429    26.0
# 430    29.0
# 431    27.0
# Name: MPG_Highway, Length: 432, dtype: float64

# %%
data['Weight'].fillna(data['Weight'].mean()) #Weight column filled null values with its mean
# Out:
# 0      4451.0
# 1      2778.0
# 2      3230.0
# 3      3575.0
# 4      3880.0
#         ...
# 427    3450.0
# 428    3450.0
# 429    3653.0
# 430    2822.0
# 431    3823.0
# Name: Weight, Length: 432, dtype: float64

# %%
data['Wheelbase'].fillna(data['Wheelbase'].mean()) #Wheelbase column filled null values with its mean
# Out:
# 0      106.0
# 1      101.0
# 2      105.0
# 3      108.0
# 4      115.0
#        ...
# 427    105.0
# 428    105.0
# 429    110.0
# 430    101.0
# 431    109.0
# Name: Wheelbase, Length: 432, dtype: float64

# %%
data['Length'].fillna(data['Length'].mean()) #Wheelbase column filled null values with its mean
# Out:
# 0      189.0
# 1      172.0
# 2      183.0
# 3      186.0
# 4      197.0
#        ...
# 427    186.0
# 428    186.0
# 429    190.0
# 430    180.0
# 431    186.0
# Name: Length, Length: 432, dtype: float64

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# **2. ----Value Counts of Make, Model, Type, Origin----**

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [markdown]
# **2.1 "Make" Column**

# %%
data['Make'].value_counts()
# Out:
# Make
# Toyota           32
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Mitsubishi       13
# Dodge            13
# Jaguar           12
# Hyundai          12
# Volvo            12
# Mazda            11
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Cadillac          8
# GMC               8
# Saturn            8
# Suzuki            8
# Infiniti          8
# Acura             7
# Porsche           7
# Saab              7
# Oldsmobile        3
# Jeep              3
# Land Rover        3
# MINI              2
# Isuzu             2
# Scion             2
# Hummer            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
data['Make'].value_counts().plot(kind='bar', color='#B19CD9')
plt.title('Count By Vehicle Make', pad=15, fontweight='bold', fontsize=15)     
plt.ylabel('Number of Vehicles', fontweight='bold',fontsize=15, labelpad=15) 
plt.xlabel('Vehicle Type', fontweight='bold', fontsize=15,  labelpad=15)

plt.show();

# %% [markdown]
# **2.2 "Model" Column**

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
data['Model'].value_counts()
# Out:
# Model
# G35 4dr                             2
# C240 4dr                            2
# C320 4dr                            2
# RSX Type S 2dr                      1
# TSX 4dr                             1
#                                    ..
# RS 6 4dr                            1
# TT 1.8 convertible 2dr (coupe)      1
# TT 1.8 Quattro 2dr (convertible)    1
# TT 3.2 coupe 2dr (convertible)      1
# A4 3.0 4dr                          1
# Name: count, Length: 425, dtype: int64

# %% [markdown]
# **2.3 "Type" Column**

# %%
data['Type'].value_counts()
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     49
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64

# %%
data['Type'].value_counts().plot(kind = 'bar')
plt.title('Count By Vehicle Types', pad=15, fontweight='bold')     
plt.ylabel('Number of Vehicles', fontweight='bold',fontsize=12, labelpad=15) 
plt.xlabel('Vehicle Type', fontweight='bold', fontsize=12,  labelpad=15)

plt.show();

# %% [markdown]
# **2.4 "Origin" Column**

# %%
data['Origin'].value_counts()
# Out:
# Origin
# Asia      158
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
counts = data['Origin'].value_counts()
labels = counts.index
sizes = counts.values


colors = ['#FFA500', '#FF4500', '#FF0000']  

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors[:len(sizes)],
        autopct='%1.1f%%', startangle=90,
        textprops={'fontsize': 14, 'fontweight': 'bold'}, explode=[0.05] + [0]*(len(sizes)-1))

plt.title('Vehicle Origins Distribution', fontsize=18, fontweight='bold')
plt.axis('equal')  # Keep it circular
plt.show()

# %% [markdown]
# **3. ----Filtering Records----**

# %%
data['Origin'].value_counts().plot(

# %% [markdown]
# **3.1 Records where Origin is Asia or USA**

# %%
data[data['Origin'].isin(['Asia', 'USA'])]
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %% [markdown]
# **3.2 Records where Type is SUV or Sports**

# %%
data[data['Type'].isin(['SUV', 'Sports'])]
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 20         Audi                          RS 6 4dr  Sports  Europe      Front
# 21         Audi    TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front
# 22         Audi  TT 1.8 Quattro 2dr (convertible)  Sports  Europe        All
# ..          ...                               ...     ...     ...        ...
# 382      Toyota                              RAV4     SUV    Asia        All
# 399      Toyota                   Celica GT-S 2dr  Sports    Asia      Front
# 400      Toyota        MR2 Spyder convertible 2dr  Sports    Asia       Rear
# 405  Volkswagen                        Touareg V6     SUV  Europe        All
# 420       Volvo                           XC90 T6     SUV  Europe        All
#
# ...

# %% [markdown]
# **3.3 Records where Model is G35 4dr or C320 4dr**

# %%
data[data['Model'].isin(['G35 4dr', 'C320 4dr'])]
# Out:
#               Make     Model   Type  Origin DriveTrain      MSRP   Invoice  \
# 183       Infiniti   G35 4dr  Sedan    Asia       Rear  $28,495   $26,157
# 185       Infiniti   G35 4dr  Sedan    Asia        All  $32,445   $29,783
# 262  Mercedes-Benz  C320 4dr  Sedan  Europe       Rear  $37,630   $35,046
# 263  Mercedes-Benz  C320 4dr  Sedan  Europe        All  $38,830   $36,162
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 183         3.5        6.0       260.0      18.0         26.0  3336.0
# 185         3.5        6.0       260.0      18.0         26.0  3677.0
# 262         3.2        6.0       215.0      20.0         26.0  3450.0
# 263         3.2        6.0       215.0      19.0         27.0  3450.0
#
#      Wheelbase  Length
# 183      112.0   187.0
# 185      112.0   187.0
# 262      107.0   178.0
# 263      107.0   178.0

# %% [markdown]
# **3.4 Records where Make is Dodge or Land Rover or Nissan or Mitsubishi**

# %%
data[data['Make'].isin(['Dodge', 'Land Rover', 'Nissan', 'Mitsubishi'])]
# Out:
#            Make                              Model    Type  Origin DriveTrain  \
# 107       Dodge                        Durango SLT     SUV     USA        All
# 108       Dodge                        Neon SE 4dr   Sedan     USA      Front
# 109       Dodge                       Neon SXT 4dr   Sedan     USA      Front
# 110       Dodge                    Intrepid SE 4dr   Sedan     USA      Front
# 111       Dodge                    Stratus SXT 4dr   Sedan     USA      Front
# 112       Dodge                     Stratus SE 4dr   Sedan     USA      Front
# 113       Dodge                    Intrepid ES 4dr   Sedan     USA      Front
# 114       Dodge                         Caravan SE   Sedan     USA      Front
# 115       Dodge                  Grand Caravan SXT   Sedan     USA        All
# 116       Dodge       Viper SRT-10 convertible 2dr  Sports     USA       Rear
# 117       Dodge                 Dakota Regular Cab   Truck     USA       Rear
# ...

# %% [markdown]
# **4. ----Increase columns values----**

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %% [markdown]
# **4.1 Increase Cylinders's column all values by 1**

# %%
data['Cylinders'] = data['Cylinders'].apply(lambda x:x+1)

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# **Increase EngineSize's column all values by 0.3**

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        7.0       265.0      17.0         23.0  4451.0
# 1         2.0        5.0       200.0      24.0         31.0  2778.0
# 2         2.4        5.0       200.0      22.0         29.0  3230.0
# 3         3.2        7.0       270.0      20.0         28.0  3575.0
# 4         3.5        7.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data['EngineSize'] = data['EngineSize'].apply(lambda x:x+0.3)

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
